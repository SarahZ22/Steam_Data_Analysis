# %%
#import dependencies
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import json
import csv

# %%
#steam spy url goes here
# url = "https://steamspy.com/app/10"

# %%
#steam spy blocks automated web scraping so we need to pass it a header telling it that we are a human using a regular web browser
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

#pull html
# r = requests.get(url, headers=header)

#create our beautiful soup object
# soup = BeautifulSoup(r.text, 'html.parser')

#we need this later when looping through all genres
stop = BeautifulSoup('''<br/>''', 'html.parser')
stop_point = stop.find("br")

# %%
dataframe_of_steam_ids = pd.read_csv('final-csv-11.csv')

# dataframe_of_steam_ids

list_of_steam_ids = dataframe_of_steam_ids["1295722"]

# list_of_steam_ids = dataframe_of_steam_ids["246280"]

# type(list_of_steam_ids)

# for index, row in list_of_steam_ids.iterrows():
#     print(row['5'])
    
#list_of_steam_ids = ['10', '10090', '10180', '1022450', '102500', '1046030', '1046930', '104900', '10500', '105450', '105600', '1057090', '1066780', '10680', '107100', '107410', '1080110', '1085660', '108600', '108710', '108800', '1089350', '1089980', '1094520', '109600', '1097150', '1097840', '1100600', '11020', '1102190', '110800', '1113000', '1118200', '1121910', '1128000', '113020', '113200', '113400', '1145360', '1147560', '1151340', '1151640', '115320', '1158310', '1172380', '1172620', '1174180', '1189630', '1190460', '12100', '12110', '12120', '1213210', '1217060', '12200', '12210', '12220', '1222140', '1222680', '1237970', '1250', '1250410', '1281930', '1284410', '1286830', '1289310', '12900', '130', '15100', '15620', '17080', '17300', '17390', '17410', '17450', '17460', '17470', '17480', '17520', '19900', '200210', '200260', '200510', '200710', '201790', '201810', '201870', '202170', '202970', '203140', '203160', '203290', '203770', '204100', '204300', '204340', '204360', '204450', '204880', '20500', '20510', '205100', '206190', '206210', '206420', '206440', '206500', '207140', '207610', '208090', '208140', '208480', '208580', '208650', '20900', '209000', '209080', '209160', '20920', '209650', '209870', '210770', '21090', '210970', '21100', '211400', '211420', '211500', '211820', '212070', '212480', '212500', '212680', '213610', '213670', '214340', '214420', '214490', '214510', '214560', '214950', '215530', '21690', '217980', '218230', '218620', '218640', '218680', '219150', '219640', '219740', '219890', '219990', '220', '220200', '220240', '220440', '220780', '221040', '221100', '221260', '221380', '221640', '221680', '221910', '222480', '222880', '22300', '223100', '22320', '22330', '223470', '22370', '223710', '223750', '22380', '224260', '224480', '224540', '224600', '224760', '22490', '225080', '225260', '225540', '225840', '226700', '226840', '226860', '227300', '227940', '2280', '228200', '228280', '228300', '228380', '230230', '230290', '230410', '231160', '231430', '232090', '232430', '232890', '233130', '233270', '233290', '233450', '233720', '233860', '233980', '234140', '234630', '234650', '234670', '235460', '235540', '235600', '236090', '236110', '236390', '236430', '236450', '236850', '236870', '237110', '237930', '237990', '238010', '238090', '238320', '238370', '238430', '238460', '238960', '239030', '239140', '239160', '239350', '239820', '240', '24010', '240720', '240760', '241540', '241560', '241600', '241930', '24200', '242050', '24240', '242680', '242700', '242720', '242760', '242860', '242920', '243470', '244160', '244210', '244450', '244850', '244930', '245170', '245550', '245620', '246420', '246620', '246900', '247080', '24740', '247730', '248390', '248570', '248610', '248820', '249050', '249130', '24960', '24980', '250320', '250400', '250600', '250760', '250900', '251060', '251570', '251990', '252150', '252490', '252950', '253230', '253250', '253710', '254700', '255220', '255710', '256290', '257510', '257850', '258520', '259080', '2600', '260230', '261030', '261550', '261570', '261640', '261820', '262060', '262410', '263280', '
513710', '516750', '517630', '518790', '519190', '519860', '524220', '526870', '527230', '527430', '531510', '532210', '533300', '535230', '535930', '536220', '544810', '544920', '546560', '548430', '548570', '550', '550650', '550900', '55100', '55150', '552100', '55230', '552500', '552520', '552990', '553640', '554620', '555160', '555220', '555570', '557340', '557600', '560130', '563560', '567640', '568220', '569480', '570', '570940', '571740', '57300', '573090', '57690', '578080', '578310', '581320', '582010', '582160', '582500', '582660', '583950', '584400', '588430', '588650', '589290', '590380', '594570', '594650', '597170', '599140', '6000', '601150', '601430', '601510', '6020', '602520', '603850', '6060', '606150', '606280', '606880', '609320', '611500', '611790', '612880', '613100', '617290', '620', '620980', '621060', '622650', '625960', '626690', '627270', '629730', '629760', '630', '630100', '632360', '632470', '633230', '63380', '635260', '636480', '637090', '637650', '638230', '638970', '639790', '640820', '641320', '641990', '644560', '644570', '644930', '645630', '646570', '646910', '648350', '648800', '652980', '653530', '657200', '65800', '65930', '65980', '666140', '666220', '668630', '67370', '673950', '674020', '674940', '675010', '677620', '678950', '678960', '683320', '6860', '686810', '690790', '6910', '692850', '698780', '70', '70000', '700330', '70300', '703080', '704270', '704850', '706220', '706990', '712100', '71340', '714010', '72850', '728880', '729040', '730', '731490', '732430', '736190', '736220', '736260', '737800', '738060', '742120', '743450', '744900', '745920', '750920', '751780', '752590', '753640', '755790', '760060', '761890', '766570', '7670', '773951', '774171', '774361', '774861', '779340', '782330', '787480', '787860', '7940', '794260', '80', '805550', '809960', '812140', '812810', '813630', '813780', '813820', '814380', '815370', '8190', '823130', '823500', '824270', '834910', '836620', '838350', '841370', '843380', '844870', '845070', '848450', '8500', '851100', '851850', '858810', '859570', '859580', '863550', '866800', '871720', '872790', '878750', '880940', '881100', '882100', '883710', '884660', '8850', '8870', '8930', '893520', '895400', '8980', '900883', '903950', '905370', '9200', '928600', '933480', '939960', '9420', '942970', '943700', '94400', '9450', '945360', '9480', '950670', '952060', '953490', '955050', '955900', '958260', '960090', '960170', '96100', '962130', '962730', '967050', '969990', '973760', '976310', '976730', '977950', '985890', '9900', '991780', '992300', '994280', '996470', '996580', '998940', '99900']

# list_of_steam_ids = ['10', '10090', '10180', '1022450', '102500', '1046030', '1046930', '104900', '10500', '105450', '105600', '1057090', '1066780', '10680', '107100', '107410', '1080110', '1085660', '108600', '108710', '108800', '1089350', '1089980', '1094520', '109600', '1097150', '1097840', '1100600', '11020', '1102190', '110800']

#list_of_steam_ids = ['10', '10090', '10180', '1022450', '102500', '1046030', '1046930', '104900', '10500', '105450', '105600']

# %%
# def find_by_label(soup, label):
#     return soup.find("div", text=re.compile(label)).next_sibling

# %%
# #find game title
# title_raw = soup.find("h3")
# title = title_raw.get_text()
# print(title)

# %%
# #find the developer
# developer = soup.find(text="Developer:")
# developer_next = developer.parent.findNext()
# developer_text = developer_next.get_text()
# print(developer_text)

# %%
# #find the publisher
# publisher = soup.find(text="Publisher:")
# publisher_next = publisher.parent.findNext()
# publisher_text = publisher_next.get_text()
# print(publisher_text)

# %%
# #find the metascore
# metascore = soup.find('strong', text="Metascore:")
# metascore_next = metascore.next_sibling.strip()
# print(metascore_next)

# %%
# #find the number of owners
# owners = soup.find('strong', text="Owners")
# owners_next = owners.next_sibling.strip()
# owners_next = owners_next[2:]
# print(owners_next)

# %%
#find genre(s)
# genre = soup.find('strong', text="Genre:")
# genre_parent = genre.parent()
# i = 13
# end_of_line = False
# list_of_genres = []
# while end_of_line == False:
#         if genre_parent[i] == stop_point:
#             end_of_line = True
#         else:
#             list_of_genres.append(genre_parent[i].get_text())
#             i = i+1

# list_of_genres

# %%
#find tags?
#soup
# tags = soup.find(text="Tags:")
# tags = tags.findNext()
# while (more_tags == True):
#     print(tag2)
#     if (tags == "<br/>"):
#         more_tags = False
#     else:
#         tag2.append(tags.get_text())
#         tags = tags.findNext()
#     list_of_tags.append(tag2)

#tags = soup.find(text="Tags:")
#tags = tags.findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext().findNext()
#tags

# %%
#find title
#soup
# title = soup.find("meta")
# title = title.findNext().findNext().findNext()
# title["content"]
# if (title["content"] == " - "):
#     print("winner!")
# #title

# %%
#find price
# price = soup.find('strong', text="Price:")
# price_next = price.next_sibling.strip()
# price_next

# %%
# list_of_columns = ["appid","Name","Developer","Publisher","Owners","Metascore","Genre(s)","Tags"]
#steam_spy_df = pd.DataFrame(columns=list_of_columns)

u = 0
# u = 1300000
#u = 29640

list_of_names = []
list_of_developers = []
list_of_publishers = []
list_of_metascores = []
list_of_owners = []
list_of_genres = []
list_of_tags = []
list_of_prices = []

for z in list_of_steam_ids:
    print("Trying #" + str(z))
    url = "https://steamspy.com/app/" + str(z)
    print(url)
    r = requests.get(url, headers=header)
    soup = BeautifulSoup(r.text, 'html.parser')
    ktitle = soup.find("meta")
    try:
        ktitle = ktitle.findNext().findNext().findNext()
        if (ktitle["content"] == " - "):
            u = u + 1
            print("DID NOT WORK")
            list_of_names.append("n/a")
            list_of_developers.append("n/a")
            list_of_publishers.append("n/a")
            list_of_metascores.append("n/a")
            list_of_owners.append("n/a")
            list_of_genres.append("n/a")
            list_of_tags.append("n/a")
            list_of_prices.append("n/a")
        else:
            title_raw = soup.find("h3")
            title = title_raw.get_text()
            if title == "":
                print("oops")
                list_of_names.append("n/a")
            else:
                more_tags = 1
                list_of_names.append(title)
                developer = soup.find(text="Developer:")
                try:
                    developer_next = developer.parent.findNext()
                    developer_text = developer_next.get_text()
                    list_of_developers.append(developer_text)
                except AttributeError:
                    list_of_developers.append("n/a")
                try:
                    publisher = soup.find(text="Publisher:")
                    publisher_next = publisher.parent.findNext()
                    publisher_text = publisher_next.get_text()
                    list_of_publishers.append(publisher_text)
                except AttributeError:
                    list_of_publishers.append("n/a")
                try:
                    metascore = soup.find('strong', text="Metascore:")
                    metascore_next = metascore.next_sibling.strip()
                    list_of_metascores.append(metascore_next)
                except AttributeError:
                    print("No Metascore!")
                    list_of_metascores.append("n/a")
                try:
                    owners = soup.find('strong', text="Owners")
                    owners_next = owners.next_sibling.strip()
                    owners_next = owners_next[2:]
                    list_of_owners.append(owners_next)
                except AttributeError:
                    list_of_owners.append("n/a")
                genre = soup.find('strong', text="Genre:")
                try:
                    genre_parent = genre.parent()
                    i = 0
                    end_of_genre_parent = len(genre_parent)
                    end_of_line = False
                    found_genre = False
                    genre2=[]
                    for i in range(len(genre_parent)):
                        if "/genre" in str(genre_parent[i]):
                            genre2.append(genre_parent[i].get_text())
                    list_of_genres.append(genre2)
                except AttributeError:
                    list_of_genres.append(genre2)
                tags = soup.find(text="Tags:")
                try:
                    tag2 = []
                    tags = tags.findNext()
                    while (more_tags == 1):
                        #print(tags.get_text())
                        if (tags.get_text() == ""):
                            more_tags = 0
                        else:
                            tag2.append(tags.get_text())
                            tags = tags.findNext()
                    list_of_tags.append(tag2)
                except AttributeError:
                    print("no tags found!")
                    list_of_tags.append("n/a")
                price = soup.find('strong', text="Price:")
                try:
                    price_next = price.next_sibling.strip()
                except AttributeError:
                    price_next = "$0.00"
                list_of_prices.append(price_next)
                u = u + 1
    except KeyError:
        u = u + 1
    except AttributeError:
        u = u + 1
        
#steam_spy_df = pd.DataFrame(columns=list_of_columns)
#steam_spy_df
# Out:
# Trying #1295723
# https://steamspy.com/app/1295723
# No Metascore!
# no tags found!
# Trying #1295724
# https://steamspy.com/app/1295724
# No Metascore!
# no tags found!
# Trying #1295725
# https://steamspy.com/app/1295725
# No Metascore!
# no tags found!
# Trying #1295726
# https://steamspy.com/app/1295726
# No Metascore!
# no tags found!
# Trying #1295727
# https://steamspy.com/app/1295727
# No Metascore!
# no tags found!
# Trying #1295740
# https://steamspy.com/app/1295740
# No Metascore!
# Trying #1295750
# https://steamspy.com/app/1295750
# No Metascore!
# Trying #1295760
# https://steamspy.com/app/1295760
# No Metascore!
# Trying #1295770
# https://steamspy.com/app/1295770
# No Metascore!
# no tags found!
# Trying #1295780
# https://steamspy.com/app/1295780
# No Metascore!
# no tags found!
# Trying #1295800
# https://steamspy.com/app/1295800
# No Metascore!
# no tags found!
# Trying #1295810
# https://steamspy.com/app/1295810
# No Metascore!
# no tags found!
# Trying #1295830
# ...

# %%
steam_spy_df = pd.DataFrame()
steam_spy_df["Name"] = list_of_names
steam_spy_df["Developers"] = list_of_developers
steam_spy_df["Publishers"] = list_of_publishers
steam_spy_df["Metascores"] = list_of_metascores
steam_spy_df["Owners"] = list_of_owners
steam_spy_df["Genres"] = list_of_genres
steam_spy_df["Tags"] = list_of_tags
steam_spy_df["Price"] = list_of_prices
steam_spy_df["App Id"] = list_of_steam_ids

# %%
print(len(list_of_steam_ids))
print(len(list_of_names))
print(len(list_of_developers))
print(len(list_of_publishers))
print(len(list_of_metascores))
print(len(list_of_owners))
print(len(list_of_genres))
print(len(list_of_tags))
print(len(list_of_prices))
# Out:
# 10614
# 10614
# 10614
# 10614
# 10614
# 10614
# 10614
# 10614
# 10614

# %%
steam_spy_df

# list_of_steam_ids
# Out:
#                                                 Name              Developers  \
# 0                            Dragon Age™ II - Legacy
# 1                  Dragon Age™ II - Promotional Pack
# 2      Dragon Age™ II - High Resolution Texture Pack
# 3         Dragon Age™ II - Signature Edition Rewards
# 4                        Dragon Age™ II - Soundtrack
# ...                                              ...                     ...
# 10609         The Tower Of TigerQiuQiu Tiger Tank 60             TigerQiuQiu
# 10610         Der Geisterturm / The Ghost Tower Demo  Graverobber Foundation
# 10611                 DIY Simulator Dedicated Server
# 10612                                   OTTI'S QUEST
# 10613           Bioshock Infinite: Columbia's Finest        Irrational Games
#
#                    Publishers Metascores       Owners  \
# 0                                    n/a  0 .. 20,000
# 1                                    n/a  0 .. 20,000
# ...

# %%
steam_spy_df.to_csv("final-project-data-11.csv")

# %%
# genre=[]
# for i in range(len(genre_parent)):
#     #print(genre_parent[i])
#     if "/genre" in str(genre_parent[i]):
#         genre.append(str(genre_parent[i].get_text()))
        

# genre
