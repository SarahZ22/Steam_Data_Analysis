# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
steam_data = pd.read_csv('final-project-data-combined.csv')

# %%
steam_data.head()
# Out:
#    App Id                   Name Developers Publishers Metascores  \
# 0       7           Steam Client        NaN        NaN        NaN
# 1       8                 winui2        NaN        NaN        NaN
# 2      10         Counter-Strike      Valve      Valve        88%
# 3      20  Team Fortress Classic      Valve      Valve        NaN
# 4      30          Day of Defeat      Valve      Valve        79%
#
#                        Owners      Genres  \
# 0               0Â ..Â 20,000        ['']
# 1               0Â ..Â 20,000        ['']
# 2  10,000,000Â ..Â 20,000,000  ['Action']
# 3    2,000,000Â ..Â 5,000,000  ['Action']
# 4   5,000,000Â ..Â 10,000,000  ['Action']
#
#                                                 Tags   Price
# 0                                                NaN  $0.00
# 1                                                NaN  $0.00
# 2  ['Action', 'FPS', 'Multiplayer', 'Shooter', 'C...  $9.99
# 3  ['Action', 'FPS', 'Multiplayer', 'Classic', 'H...  $4.99
# 4  ['FPS', 'World War II', 'Multiplayer', 'Shoote...  $4.99

# %%
new = steam_data["Owners"].str.split("Â ..Â ", n = 1, expand = True)
steam_data['Owners'].dtypes
new
# Out:
#                 0           1
# 0               0      20,000
# 1               0      20,000
# 2      10,000,000  20,000,000
# 3       2,000,000   5,000,000
# 4       5,000,000  10,000,000
# ...           ...         ...
# 95239           0      20,000
# 95240           0      20,000
# 95241           0      20,000
# 95242           0      20,000
# 95243           0      20,000
#
# [95244 rows x 2 columns]

# %%
steam_data["min owners"] = new[0]
steam_data["max owners"] = new[1]
steam_data.drop(columns =["Owners"], inplace = True)

# %%
steam_data
# Out:
#         App Id                                    Name  \
# 0            7                            Steam Client
# 1            8                                  winui2
# 2           10                          Counter-Strike
# 3           20                   Team Fortress Classic
# 4           30                           Day of Defeat
# ...        ...                                     ...
# 95239  1474820  The Tower Of TigerQiuQiu Tiger Tank 60
# 95240  1474960  Der Geisterturm / The Ghost Tower Demo
# 95241  1475910          DIY Simulator Dedicated Server
# 95242  1476030                            OTTI'S QUEST
# 95243  2028850    Bioshock Infinite: Columbia's Finest
#
#                    Developers              Publishers Metascores  \
# 0                         NaN                     NaN        NaN
# 1                         NaN                     NaN        NaN
# 2                       Valve                   Valve        88%
# 3                       Valve                   Valve        NaN
# 4                       Valve                   Valve        79%
# ...                       ...                     ...        ...
# 95239             TigerQiuQiu             TigerQiuQiu        NaN
# 95240  Graverobber Foundation  Graverobber Foundation        NaN
# 95241                     NaN                     NaN        NaN
# 95242                     NaN                     NaN        NaN
# 95243        Irrational Games                2K Games        NaN
#
#                               Genres  \
# 0                               ['']
# 1                               ['']
# 2                         ['Action']
# 3                         ['Action']
# 4                         ['Action']
# ...                              ...
# 95239  ['Action', 'Casual', 'Indie']
# 95240                           ['']
# 95241                           ['']
# 95242                           ['']
# 95243                     ['Action']
#
#                                                     Tags   Price  min owners  \
# 0                                                    NaN  $0.00            0
# 1                                                    NaN  $0.00            0
# 2      ['Action', 'FPS', 'Multiplayer', 'Shooter', 'C...  $9.99   10,000,000
# 3      ['Action', 'FPS', 'Multiplayer', 'Classic', 'H...  $4.99    2,000,000
# 4      ['FPS', 'World War II', 'Multiplayer', 'Shoote...  $4.99    5,000,000
# ...                                                  ...     ...         ...
# 95239                                                NaN  $0.74            0
# 95240                                                NaN  $0.00            0
# 95241                                                NaN  $0.00            0
# 95242                                                NaN  $0.00            0
# 95243                  ['Action', 'FPS', 'Singleplayer']  $4.99            0
#
#        max owners
# 0          20,000
# 1          20,000
# 2      20,000,000
# 3       5,000,000
# 4      10,000,000
# ...           ...
# 95239      20,000
# 95240      20,000
# 95241      20,000
# 95242      20,000
# 95243      20,000
#
# [95244 rows x 10 columns]

# %%
# new_max = steam_data["max"].str.split(".", n = 1, expand = True)
# new_max[1]

# %%
# steam_data["max"] = new_max[1]
# steam_data

# %%
#  steam_data["Genres"] = steam_data["Genres"].apply(eval)

# %%
steam_data_clean = steam_data.dropna(subset=["Genres", "Developers","Tags"])

# %%
steam_data_clean.shape
# Out:
# (52432, 10)

# %%
steam_data_clean.isna().sum()
# Out:
# App Id            0
# Name              0
# Developers        0
# Publishers     4139
# Metascores    48427
# Genres            0
# Tags              0
# Price             0
# min owners        0
# max owners        0
# dtype: int64

# %%
# steam_data_clean["Genres"] = steam_data_clean["Genres"].replace("'","")

# %%
# steam_data_clean.head()

# %%
# stripped_genres = []

# for i in steam_data_clean["Genres"]:
#     x = i.replace("'","")
#     stripped_genres.append(x)
    
# len(stripped_genres)

# %%
# stripped_genres

# %%
# steam_data_clean["Genres"] = stripped_genres

# %%
# steam_data_clean.head()

# %%
# steam_data.head()

# %%
steam_data_clean["Genres"] = steam_data_clean["Genres"].apply(eval)
# Out:
# <ipython-input-13-3de5af67e85d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam_data_clean["Genres"] = steam_data_clean["Genres"].apply(eval)

# %%
genre_dict = {}
for i in steam_data_clean["Genres"]:
    for j in i:
        if j not in genre_dict:
            genre_dict[j] = 1
        else:
            genre_dict[j] += 1
genre_dict
# Out:
# {'Action': 21864,
#  'Free to Play': 4121,
#  'Strategy': 10259,
#  'Adventure': 16926,
#  '': 1074,
#  'Indie': 31196,
#  'RPG': 8691,
#  'Casual': 16215,
#  'Racing': 1954,
#  'Simulation': 10985,
#  'Animation & Modeling': 384,
#  'Video Production': 236,
#  'Sports': 2499,
#  'Massively Multiplayer': 1925,
#  'Early Access': 3929,
#  'in Early Access': 2479,
#  'Photo Editing': 86,
#  'Utilities': 673,
#  'Design & Illustration': 678,
#  'Education': 293,
#  'Game Development': 76,
#  'Software Training': 168,
#  'Web Publishing': 365,
#  'Violent': 906,
#  'Gore': 489,
#  'Audio Production': 187,
#  'Nudity': 311,
#  'Sexual Content': 271,
#  'Documentary': 52,
#  'Episodic': 163,
#  'Accounting': 13,
#  'Movie': 240,
#  'Short': 30,
#  'Tutorial': 30,
#  '360 Video': 14,
#  '360 V': 1}

# %%
genre_explode = steam_data_clean.explode("Genres")
genre_explode
# Out:
#         App Id                                  Name         Developers  \
# 2           10                        Counter-Strike              Valve
# 3           20                 Team Fortress Classic              Valve
# 4           30                         Day of Defeat              Valve
# 5           40                    Deathmatch Classic              Valve
# 6           50             Half-Life: Opposing Force   Gearbox Software
# ...        ...                                   ...                ...
# 95055  1465120                               skelets  Sokpop Collective
# 95062  1465350                            Model City               GTGD
# 95062  1465350                            Model City               GTGD
# 95062  1465350                            Model City               GTGD
# 95243  2028850  Bioshock Infinite: Columbia's Finest   Irrational Games
#
#               Publishers Metascores      Genres  \
# 2                  Valve        88%      Action
# 3                  Valve        NaN      Action
# 4                  Valve        79%      Action
# 5                  Valve        NaN      Action
# 6                  Valve        NaN      Action
# ...                  ...        ...         ...
# 95055  Sokpop Collective        NaN       Indie
# 95062               GTGD        NaN      Casual
# 95062               GTGD        NaN       Indie
# 95062               GTGD        NaN  Simulation
# 95243           2K Games        NaN      Action
#
#                                                     Tags   Price  min owners  \
# 2      ['Action', 'FPS', 'Multiplayer', 'Shooter', 'C...  $9.99   10,000,000
# 3      ['Action', 'FPS', 'Multiplayer', 'Classic', 'H...  $4.99    2,000,000
# 4      ['FPS', 'World War II', 'Multiplayer', 'Shoote...  $4.99    5,000,000
# 5      ['Action', 'FPS', 'Classic', 'Multiplayer', 'S...  $4.99    5,000,000
# 6      ['FPS', 'Action', 'Classic', 'Sci-fi', 'Single...  $4.99    5,000,000
# ...                                                  ...     ...         ...
# 95055  ['Action', 'Platformer', 'Fighting', '2D Fight...  $2.99            0
# 95062  ['Casual', 'Relaxing', 'City Builder', 'Simula...  $5.99            0
# 95062  ['Casual', 'Relaxing', 'City Builder', 'Simula...  $5.99            0
# 95062  ['Casual', 'Relaxing', 'City Builder', 'Simula...  $5.99            0
# 95243                  ['Action', 'FPS', 'Singleplayer']  $4.99            0
#
#        max owners
# 2      20,000,000
# 3       5,000,000
# 4      10,000,000
# 5      10,000,000
# 6      10,000,000
# ...           ...
# 95055      20,000
# 95062      20,000
# 95062      20,000
# 95062      20,000
# 95243      20,000
#
# [139783 rows x 10 columns]

# %%
# steam_data_clean.head()

# %%
# len(steam_data_clean["Genres"].iloc[0].replace("[", "").replace("]", "").split(","))

# %%
# i = 3
# stored_data = []
# genre_series = []

# #for i in range(5):
# if len(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")) == 1:
#     stored_data.append(steam_data_clean.iloc[i, :])
#     genre_series.append(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")[0])
# elif len(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")) == 2:
#     genre_list = steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")
#     genre_series.append(genre_list[0])
#     genre_series.append(genre_list[1])
#     stored_data.append(steam_data_clean.iloc[i, :])
#     stored_data.append(steam_data_clean.iloc[i, :])
# elif len(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")) == 3:
#     genre_list = steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")
#     genre_series.append(genre_list[0])
#     genre_series.append(genre_list[1])
#     genre_series.append(genre_list[2])
#     stored_data.append(steam_data_clean.iloc[i, :])
#     stored_data.append(steam_data_clean.iloc[i, :])
#     stored_data.append(steam_data_clean.iloc[i, :])
# elif len(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")) == 4:
#     genre_list = steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")
#     genre_series.append(genre_list[0])
#     genre_series.append(genre_list[1])
#     genre_series.append(genre_list[2])
#     genre_series.append(genre_list[3])
#     stored_data.append(steam_data_clean.iloc[i, :])
#     stored_data.append(steam_data_clean.iloc[i, :])
#     stored_data.append(steam_data_clean.iloc[i, :])
#     stored_data.append(steam_data_clean.iloc[i, :])
# elif len(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")) == 5:
#     genre_list = steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")
#     genre_series.append(genre_list[0])
#     genre_series.append(genre_list[1])
#     genre_series.append(genre_list[2])
#     genre_series.append(genre_list[3])
#     genre_series.append(genre_list[4])
#     stored_data.append(steam_data_clean.iloc[i, :])
#     stored_data.append(steam_data_clean.iloc[i, :])
#     stored_data.append(steam_data_clean.iloc[i, :])
#     stored_data.append(steam_data_clean.iloc[i, :])
#     stored_data.append(steam_data_clean.iloc[i, :])

# %%
# stored_data

# %%
# test = pd.DataFrame(stored_data)

# test

# %%
# genre_series

# %%
# # create new dataframe where every column is the same EXCEPT the genres. if there is a game with 2 genres, make 2 rows where 
# # column is the same except for the genre.

# stored_data = []
# genre_series = []

# for i in range(steam_data_clean.shape[0]):
#     if len(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")) == 1:
#         stored_data.append(steam_data_clean.iloc[i, :])
#         genre_series.append(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")[0])
#     elif len(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")) == 2:
#         genre_list = steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")
#         genre_series.append(genre_list[0])
#         genre_series.append(genre_list[1])
#         stored_data.append(steam_data_clean.iloc[i, :])
#         stored_data.append(steam_data_clean.iloc[i, :])
#     elif len(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")) == 3:
#         genre_list = steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")
#         genre_series.append(genre_list[0])
#         genre_series.append(genre_list[1])
#         genre_series.append(genre_list[2])
#         stored_data.append(steam_data_clean.iloc[i, :])
#         stored_data.append(steam_data_clean.iloc[i, :])
#         stored_data.append(steam_data_clean.iloc[i, :])
#     elif len(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")) == 4:
#         genre_list = steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")
#         genre_series.append(genre_list[0])
#         genre_series.append(genre_list[1])
#         genre_series.append(genre_list[2])
#         genre_series.append(genre_list[3])
#         stored_data.append(steam_data_clean.iloc[i, :])
#         stored_data.append(steam_data_clean.iloc[i, :])
#         stored_data.append(steam_data_clean.iloc[i, :])
#         stored_data.append(steam_data_clean.iloc[i, :])
#     elif len(steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")) == 5:
#         genre_list = steam_data_clean["Genres"].iloc[i].replace("[", "").replace("]", "").split(",")
#         genre_series.append(genre_list[0])
#         genre_series.append(genre_list[1])
#         genre_series.append(genre_list[2])
#         genre_series.append(genre_list[3])
#         genre_series.append(genre_list[4])
#         stored_data.append(steam_data_clean.iloc[i, :])
#         stored_data.append(steam_data_clean.iloc[i, :])
#         stored_data.append(steam_data_clean.iloc[i, :])
#         stored_data.append(steam_data_clean.iloc[i, :])
#         stored_data.append(steam_data_clean.iloc[i, :])

# %%
# genre_df = pd.DataFrame(stored_data)

# genre_df.head(10)

# %%
# genre_df["Genres"] = genre_series

# genre_df.head()

# %%
# # create new dataframe where every column is the same EXCEPT the genres. if there is a game with 2 genres, make 2 rows where 
# # column is the same except for the genre.

stored_data_tags = []
Tags_series = []

for i in range(genre_explode.shape[0]):
    if len(steam_data_clean["Tags"].iloc[i].replace("[", "").replace("]", "").split(",")) == 1:
        stored_data_tags.append(steam_data_clean.iloc[i, :])
        genre_series.append(steam_data_clean["Tags"].iloc[i].replace("[", "").replace("]", "").split(",")[0])
    elif len(steam_data_clean["Tags"].iloc[i].replace("[", "").replace("]", "").split(",")) == 2:
        genre_list = steam_data_clean["Tags"].iloc[i].replace("[", "").replace("]", "").split(",")
        genre_series.append(genre_list[0])
        genre_series.append(genre_list[1])
        stored_data.append(steam_data_clean.iloc[i, :])
        stored_data.append(steam_data_clean.iloc[i, :])
    elif len(steam_data_clean["Tags"].iloc[i].replace("[", "").replace("]", "").split(",")) == 3:
        genre_list = steam_data_clean["Tags"].iloc[i].replace("[", "").replace("]", "").split(",")
        genre_series.append(genre_list[0])
        genre_series.append(genre_list[1])
        genre_series.append(genre_list[2])
        stored_data.append(steam_data_clean.iloc[i, :])
        stored_data.append(steam_data_clean.iloc[i, :])
        stored_data.append(steam_data_clean.iloc[i, :])
    elif len(steam_data_clean["Tags"].iloc[i].replace("[", "").replace("]", "").split(",")) == 4:
        genre_list = steam_data_clean["Tags"].iloc[i].replace("[", "").replace("]", "").split(",")
        genre_series.append(genre_list[0])
        genre_series.append(genre_list[1])
        genre_series.append(genre_list[2])
        genre_series.append(genre_list[3])
        stored_data.append(steam_data_clean.iloc[i, :])
        stored_data.append(steam_data_clean.iloc[i, :])
        stored_data.append(steam_data_clean.iloc[i, :])
        stored_data.append(steam_data_clean.iloc[i, :])
    elif len(steam_data_clean["Tags"].iloc[i].replace("[", "").replace("]", "").split(",")) == 5:
        genre_list = steam_data_clean["Tags"].iloc[i].replace("[", "").replace("]", "").split(",")
        genre_series.append(genre_list[0])
        genre_series.append(genre_list[1])
        genre_series.append(genre_list[2])
        genre_series.append(genre_list[3])
        genre_series.append(genre_list[4])
        stored_data.append(steam_data_clean.iloc[i, :])
        stored_data.append(steam_data_clean.iloc[i, :])
        stored_data.append(steam_data_clean.iloc[i, :])
        stored_data.append(steam_data_clean.iloc[i, :])
        stored_data.append(steam_data_clean.iloc[i, :])

# %%
genre_explode["Tags"] = genre_explode["Tags"].apply(eval)

# %%
tag_dict = {}
for i in genre_explode["Tags"]:
    for j in i:
        if j not in tag_dict:
            tag_dict[j] = 1
        else:
            tag_dict[j] += 1
tag_dict
# Out:
# {'Action': 71236,
#  'FPS': 7075,
#  'Multiplayer': 16334,
#  'Shooter': 9317,
#  'Classic': 3216,
#  'Team-Based': 1436,
#  'First-Person': 9470,
#  'Competitive': 2327,
#  'Tactical': 3915,
#  "1990's": 1094,
#  'e-sports': 715,
#  'PvP': 3951,
#  'Old School': 2162,
#  'Military': 1727,
#  'Strategy': 37160,
#  'Survival': 8225,
#  'Score Attack': 1324,
#  '1980s': 991,
#  'Assassin': 295,
#  'Violent': 10880,
#  'Hero Shooter': 261,
#  'Class-Based': 370,
#  'Co-op': 8181,
#  'Fast-Paced': 3256,
#  'Retro': 8125,
#  'Online Co-Op': 3710,
#  'Mod': 308,
#  'Remake': 506,
#  'Funny': 9873,
#  'World War II': 1091,
#  'War': 2561,
#  'Historical': 2418,
#  'Singleplayer': 37746,
#  'Difficult': 9931,
#  'World War I': 214,
#  'Arena Shooter': 1203,
#  'Sci-fi': 8975,
#  'Gore': 8665,
#  'Aliens': 1403,
#  'Adventure': 61738,
#  'Atmospheric': 14657,
#  'Story Rich': 11038,
#  'Silent Protagonist': 253,
#  'Great Soundtrack': 12449,
#  'Puzzle': 14088,
#  'Moddable': 1485,
#  'Cyberpunk': 1519,
#  'Space': 4916,
#  'Memes': 2594,
#  'Conspiracy': 248,
#  'Psychological Horror': 4153,
#  'Platformer': 8669,
#  '3D': 4706,
#  'Cult Classic': 663,
#  'Anime': 9253,
#  'Sports': 10163,
#  'Linear': 1222,
#  'Open World': 8811,
#  'Simulation': 38171,
#  'Dark': 3248,
#  'Masterpiece': 676,
#  'Zombies': 3659,
#  'Short': 2892,
#  'Dystopian ': 726,
#  'Physics': 4200,
#  'Horror': 9333,
#  'Sandbox': 6284,
#  'Realistic': 3533,
#  'Massively Multiplayer': 9596,
#  'Comedy': 5654,
#  'Futuristic': 1989,
#  'Benchmark': 42,
#  'Free to Play': 17217,
#  'Post-apocalyptic': 2194,
#  'Episodic': 677,
#  'Cinematic': 701,
#  'Puzzle-Platformer': 3160,
#  '3D Platformer': 1940,
#  'Female Protagonist': 7168,
#  'Science': 712,
#  'Dark Humor': 1276,
#  'Cartoony': 2729,
#  'Trading': 545,
#  'Robots': 1597,
#  'Cartoon': 1746,
#  'Crafting': 3239,
#  'Replay Value': 4200,
#  'Survival Horror': 3085,
#  'Local Co-Op': 3428,
#  'MOBA': 782,
#  'RTS': 2555,
#  'Tower Defense': 2298,
#  'RPG': 33832,
#  'Fantasy': 9332,
#  'Character Customization': 2685,
#  'Action RPG': 3202,
#  'Action-Adventure': 4053,
#  'Level Editor': 1267,
#  'Top-Down': 3842,
#  'Top-Down Shooter': 2017,
#  'Third Person': 5266,
#  'PvE': 1694,
#  'Third-Person Shooter': 1839,
#  'Naval': 524,
#  'Indie': 100243,
#  'Fighting': 2093,
#  'Isometric': 1967,
#  'Twin Stick Shooter': 1304,
#  'Dark Fantasy': 1840,
#  'Swordplay': 614,
#  'Magic': 2050,
#  'Stealth': 2103,
#  'Multiple Endings': 2477,
#  'Medieval': 2245,
#  'Hack and Slash': 2650,
#  'Hacking': 468,
#  '2D': 18759,
#  'Real-Time with Pause': 662,
#  'Experimental': 1868,
#  'Addictive': 1123,
#  'Rogue-like': 3688,
#  'Perma Death': 1460,
#  'Space Sim': 1008,
#  'Economy': 1605,
#  'Flight': 1458,
#  '4X': 627,
#  'Casual': 58103,
#  'Loot': 1158,
#  'Crime': 818,
#  'Controller': 3365,
#  'Racing': 7335,
#  'Time Attack': 388,
#  'Arcade': 8820,
#  'Point & Click': 4115,
#  'Mystery': 3414,
#  'America': 359,
#  'Mechs': 671,
#  'Heist': 322,
#  'Split Screen': 841,
#  'Turn-Based Strategy': 3158,
#  'Turn-Based': 4486,
#  'Grand Strategy': 1033,
#  'Education': 2812,
#  'Local Multiplayer': 4141,
#  'Western': 404,
#  'Steampunk': 806,
#  'Underwater': 432,
#  'Political': 561,
#  'Alternate History': 682,
#  'Driving': 1655,
#  'Mythology': 541,
#  'Tanks': 660,
#  'Base-Building': 2057,
#  'Modern': 529,
#  '2D Fighter': 828,
#  'Martial Arts': 330,
#  'Intentionally Awkward Controls': 101,
#  'Wargame': 903,
#  'Cold War': 321,
#  'Diplomacy': 257,
#  'Naval Combat': 276,
#  'Submarine': 96,
#  'Gothic': 322,
#  'Underground': 256,
#  'Immersive Sim': 677,
#  'Exploration': 6977,
#  'Dungeon Crawler': 2390,
#  'Inventory Management': 545,
#  'Animation & Modeling': 1623,
#  'Video Production': 899,
#  'Software': 897,
#  'Movie': 646,
#  'Real-Time': 899,
#  'Pixel Graphics': 10532,
#  'Resource Management': 2130,
#  'Tactical RPG': 965,
#  '2.5D': 1117,
#  'Demons': 722,
#  'Lovecraftian': 638,
#  'Stylized': 2915,
#  'Blood': 770,
#  "Shoot 'Em Up": 3233,
#  'Combat': 1413,
#  '2D Platformer': 2089,
#  'Vampire': 293,
#  'Supernatural': 498,
#  'Immersive': 160,
#  'Bullet Time': 465,
#  'Management': 3775,
#  'Building': 3989,
#  'Family Friendly': 6919,
#  'City Builder': 1371,
#  'Destruction': 1055,
#  'Politics': 457,
#  'Capitalism': 377,
#  'Combat Racing': 347,
#  'Automobile Sim': 1104,
#  'Vehicular Combat': 364,
#  'Music': 1871,
#  'Offroad': 243,
#  'Hex Grid': 554,
#  'Turn-Based Combat': 2337,
#  'Match 3': 910,
#  'Cute': 7315,
#  'Clicker': 1296,
#  'Colorful': 6047,
#  'Relaxing': 5252,
#  'Word Game': 362,
#  'Dinosaurs': 545,
#  'Bullet Hell': 2450,
#  'Typing': 191,
#  'Hidden Object': 2322,
#  'Touch-Friendly': 619,
#  'Sniper': 189,
#  'Comic Book': 701,
#  'Villain Protagonist': 284,
#  'Parody ': 543,
#  'God Game': 475,
#  'Mature': 1955,
#  'Psychological': 953,
#  'Surreal': 1834,
#  'Collectathon': 264,
#  '3D Vision': 471,
#  'Soundtrack': 824,
#  'Pirates': 681,
#  'Sailing': 284,
#  'Choose Your Own Adventure': 2014,
#  'Rome': 155,
#  'Card Game': 1954,
#  'Gambling': 184,
#  'Based On A Novel': 186,
#  'Epic': 267,
#  'Warhammer 40K': 138,
#  'Games Workshop': 245,
#  'Real Time Tactics': 1017,
#  'Detective': 1068,
#  "Beat 'em up": 1328,
#  'Thriller': 780,
#  'Parkour': 977,
#  'Mars': 200,
#  'Choices Matter': 3405,
#  'Nudity': 6330,
#  'Beautiful': 1736,
#  'Lara Croft': 57,
#  'Bowling': 52,
#  'Satire': 435,
#  'Co-op Campaign': 424,
#  'Turn-Based Tactics': 2060,
#  'Romance': 1716,
#  'FMV': 386,
#  'Metroidvania': 1413,
#  'Side Scroller': 3386,
#  'Philisophical': 31,
#  'Voice Control': 61,
#  'MMORPG': 1427,
#  'Walking Simulator': 2102,
#  'Experience': 316,
#  'Party-Based RPG': 1081,
#  'CRPG': 740,
#  'Minimalist': 3131,
#  'Procedural Generation': 2621,
#  '4 Player Local': 2122,
#  'Time Travel': 376,
#  'Ninja': 552,
#  'Quick-Time Events': 232,
#  'Dragons': 576,
#  'Board Game': 1457,
#  'Minigames': 330,
#  'Character Action Game': 903,
#  'Spectacle fighter': 317,
#  'LEGO': 146,
#  'Time Management': 1050,
#  'Psychedelic': 810,
#  'Rhythm': 928,
#  'Time Manipulation': 345,
#  '6DOF': 412,
#  'Unforgiving': 137,
#  'Hand-drawn': 1837,
#  'Interactive Fiction': 1476,
#  'Superhero': 366,
#  'Batman': 39,
#  'Gun Customization': 354,
#  'Mining': 402,
#  'Music-Based Procedural Generation': 258,
#  'Strategy RPG': 1089,
#  'JRPG': 2271,
#  'Motocross': 73,
#  'ATV': 17,
#  'Motorbike': 176,
#  'Bikes': 152,
#  'Transhumanism': 116,
#  'Illuminati': 545,
#  'Trains': 455,
#  'Spaceships': 51,
#  'Philosophical': 433,
#  'Looter Shooter': 150,
#  'Nostalgia': 91,
#  'On-Rails Shooter': 188,
#  'Mini Golf': 120,
#  'Golf': 177,
#  'Hunting': 444,
#  'Investigation': 746,
#  'Sequel': 173,
#  'Colony Sim': 476,
#  'Lore-Rich': 519,
#  'Abstract': 1241,
#  'Logic': 1464,
#  'Mouse only': 843,
#  'Medical Sim': 122,
#  'Noir': 473,
#  'Narrative': 123,
#  'Pinball': 234,
#  'Emotional': 655,
#  'Horses': 241,
#  'TrackIR': 221,
#  'VR': 11848,
#  'Early Access': 21236,
#  'Farming Sim': 362,
#  'Agriculture': 415,
#  'Farming': 124,
#  'Werewolves': 154,
#  'Well-Written': 13,
#  'Card Battler': 539,
#  'Deckbuilding': 487,
#  'Party': 235,
#  'Political Sim': 309,
#  'Transportation': 165,
#  'Fishing': 376,
#  '3D Fighter': 284,
#  'Ambient': 62,
#  'Conversation': 528,
#  'Drama': 1219,
#  'Visual Novel': 5475,
#  'Hentai': 625,
#  'Dog': 215,
#  'Solitaire': 219,
#  'Tabletop': 741,
#  'Life Sim': 651,
#  'Precision Platformer': 709,
#  'Sexual Content': 5384,
#  'Action Roguelike': 1659,
#  'Nonlinear': 522,
#  'Basketball': 124,
#  'Cats': 489,
#  'Trading Card Game': 470,
#  'Rogue-lite': 3057,
#  'Runner': 836,
#  'Chess': 288,
#  'Grid-Based Movement': 537,
#  'Tennis': 78,
#  'Lemmings': 95,
#  'Nature': 860,
#  'Dating Sim': 1604,
#  'LGBTQ+': 982,
#  'Programming': 392,
#  'Star Wars': 9,
#  'Narration': 1061,
#  'Asynchronous Multiplayer': 253,
#  'RPGMaker': 3114,
#  'Dynamic Narration': 231,
#  'Sokoban': 265,
#  'Kickstarter': 617,
#  'Otome': 609,
#  'Documentary': 262,
#  'Game Development': 1040,
#  'GameMaker': 617,
#  'Dungeons & Dragons': 176,
#  'Football': 412,
#  'Soccer': 420,
#  'Utilities': 2278,
#  'Party Game': 205,
#  'Automation': 278,
#  'Traditional Roguelike': 214,
#  'Photo Editing': 380,
#  'Design & Illustration': 2369,
#  'Feature Film': 26,
#  'Open World Survival Craft': 1081,
#  'Creature Collector': 114,
#  'Artificial Intelligence': 501,
#  'Reboot': 22,
#  'Skating': 32,
#  'Roguevania': 117,
#  'Text-Based': 1833,
#  'Souls-like': 601,
#  'Software Training': 878,
#  'Web Publishing': 1105,
#  'Audio Production': 676,
#  'Crowdfunded': 294,
#  'Dark Comedy': 596,
#  'Voxel': 767,
#  'Wrestling': 68,
#  'Snow': 141,
#  'Skiing': 36,
#  'Snowboarding': 33,
#  'Outbreak Sim': 101,
#  'Mystery Dungeon': 325,
#  'Archery': 195,
#  'Trivia': 254,
#  'Pool': 93,
#  'Cycling': 38,
#  'Roguelike Deckbuilder': 141,
#  'VR Only': 2759,
#  'Tutorial': 675,
#  'Skateboarding': 46,
#  'Battle Royale': 735,
#  'Steam Machine': 26,
#  'Hockey': 62,
#  'Gaming': 231,
#  'Boxing': 152,
#  'Baseball': 75,
#  'Electronic Music': 44,
#  'Spelling': 66,
#  'Social Deduction': 80,
#  'NSFW': 403,
#  'Jet': 69,
#  'Action RTS': 14,
#  'Asymmetric VR': 109,
#  'Idler': 416,
#  'Hardware': 18,
#  'Foreign': 94,
#  'BMX': 32,
#  'Auto Battler': 137,
#  '360 Video': 149,
#  'Electronic': 21,
#  'Faith': 255,
#  'Instrumental Music': 16,
#  'Breathtaking': 4,
#  '8-bit Music': 6,
#  'Rock Music': 16,
#  'Cooking': 3}

# %%
tag_explode = genre_explode.explode("Tags")
tag_explode
# Out:
#         App Id                                  Name        Developers  \
# 2           10                        Counter-Strike             Valve
# 2           10                        Counter-Strike             Valve
# 2           10                        Counter-Strike             Valve
# 2           10                        Counter-Strike             Valve
# 2           10                        Counter-Strike             Valve
# ...        ...                                   ...               ...
# 95062  1465350                            Model City              GTGD
# 95062  1465350                            Model City              GTGD
# 95243  2028850  Bioshock Infinite: Columbia's Finest  Irrational Games
# 95243  2028850  Bioshock Infinite: Columbia's Finest  Irrational Games
# 95243  2028850  Bioshock Infinite: Columbia's Finest  Irrational Games
#
#       Publishers Metascores      Genres          Tags   Price  min owners  \
# 2          Valve        88%      Action        Action  $9.99   10,000,000
# 2          Valve        88%      Action           FPS  $9.99   10,000,000
# 2          Valve        88%      Action   Multiplayer  $9.99   10,000,000
# 2          Valve        88%      Action       Shooter  $9.99   10,000,000
# 2          Valve        88%      Action       Classic  $9.99   10,000,000
# ...          ...        ...         ...           ...     ...         ...
# 95062       GTGD        NaN  Simulation            3D  $5.99            0
# 95062       GTGD        NaN  Simulation        Puzzle  $5.99            0
# 95243   2K Games        NaN      Action        Action  $4.99            0
# 95243   2K Games        NaN      Action           FPS  $4.99            0
# 95243   2K Games        NaN      Action  Singleplayer  $4.99            0
#
#        max owners
# 2      20,000,000
# 2      20,000,000
# 2      20,000,000
# 2      20,000,000
# 2      20,000,000
# ...           ...
# 95062      20,000
# 95062      20,000
# 95243      20,000
# 95243      20,000
# 95243      20,000
#
# [1238654 rows x 10 columns]

# %%
# own_med = tag_explode["max owners"].median()
# own_med
# own_max = genre_explode["max owners"].max()
# own_max
# own_med

# %%
tag_explode.to_csv('final_project_genre_tags.csv', index = False, header=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-28-4b94798d57ea> in <module>
# ----> 1 tag_explode.to_csv('final_project_genre_tags.csv', index = False, header=True)
#
# ~\.conda\New folder\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\.conda\New folder\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     182             close = False
#     183         else:
# --> 184             f, handles = get_handle(
#     185                 self.path_or_buf,
#     186                 self.mode,
#
# ~\.conda\New folder\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'final_project_genre_tags.csv'
